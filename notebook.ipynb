# %% [markdown]
# ## 1. Analysis of costs to run animal shelters
# <p>You are working as a data analyst in the animal welfare department. In preparation for next year's budget, the head of your department would like to know the total cost to shelter animals, broken down by each animal type and size combination (i.e., 'small dogs', 'large dogs', etc.). You need to prepare a table that contains this information.</p>
# <p>The total cost to shelter an animal for the year is calculated as the sum of three factors: the size and animal type, the age, and the location.</p>
# <ul>
# <li>The base cost of sheltering an animal is based upon its size and type. The costs per animal type and size are contained in the <code>size_costs</code> table. The criteria for classifying size has recently been updated, and so you will need to categorize animals based upon the following table:</li>
# </ul>
# <table>
# <thead>
# <tr>
# <th style="text-align:right;"></th>
# <th style="text-align:right;">Small</th>
# <th>Medium</th>
# <th>Large</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td style="text-align:right;">Dog</td>
# <td style="text-align:right;">&lt;= 10 lbs</td>
# <td>10 lbs &lt; and &lt;= 30 lbs</td>
# <td>30 lbs &lt;</td>
# </tr>
# <tr>
# <td style="text-align:right;">Cat</td>
# <td style="text-align:right;">&lt;= 5 lbs</td>
# <td>5 lbs &lt; and &lt;= 7 lbs</td>
# <td>7 lbs &lt;</td>
# </tr>
# <tr>
# <td style="text-align:right;">Bird</td>
# <td style="text-align:right;">&lt;= 0.7 lbs</td>
# <td>0.7 lbs &lt; and &lt;= 1.1 lbs</td>
# <td>1.1 lbs &lt;</td>
# </tr>
# </tbody>
# </table>
# <ul>
# <li>Older animals cost more, and so an age cost (contained in the <code>age_costs</code> table) is added. Each animal's age should be calculated as the age by the end of the year (December 31st, 2021).</li>
# <li>There is a location cost depending on where the animal is sheltered (contained in the <code>location_costs</code> table). </li>
# <li>The calculation should not include animals that have been sponsored by private charities (sponsored animals are listed in the <code>sponsored_animals</code> table).</li>
# </ul>
# <p>For future visualization purposes, you will also need to include a <code>percentage</code> column in your result. This percentage should reflect the fraction of the total cost to be allocated to each animal and size combination.</p>
# <p>The data you need is available in the tables shown in the database schema below.</p>
# <h5 id="databaseschema">Database Schema</h5>
# <p><img src="https://assets.datacamp.com/production/repositories/5934/datasets/a946a159c0024ee0995f7a030f2c0cf802203835/diagram.PNG" width="500" height="500"> </p>

# %%
# %%sql
# postgresql:///animal_shelters
#
#     select animalid,animaltype,
#     extract(year from age(date('2021-12-31'),date(birthdate))) as age,
#     case when animaltype='Dog' and weight<=10 then 'DS'
#     when animaltype='Dog' and weight<=30 then 'DM'
#     when animaltype='Dog' and weight>30 then 'DL'
#     when animaltype='Cat' and weight<=5 then 'CS'
#     when animaltype='Cat' and weight<=7 then 'CM'
#     when animaltype='Cat' and weight>7 then 'CL'
#     when animaltype='Bird' and weight<=0.7 then 'BS'
#     when animaltype='Bird' and weight<=1.1 then 'BM'
#     else 'BL' end as sizeid
#
#     from animals as a
#     left join location_costs as l
#     on a.location=l.location
#
#
#     where animalid not in (select sponsorid from sponsored_animals)
#     limit 5
# Out:
# 5 rows affected.
# [('968bf2e7230d2f', 'Cat', 9.0, 'CM'),
#  ('8aacfe19c56b0f', 'Dog', 8.0, 'DL'),
#  ('9617240ad5b268', 'Cat', 7.0, 'CL'),
#  ('fd7bf1fa986957', 'Dog', 4.0, 'DL'),
#  ('691081c83b1075', 'Dog', 5.0, 'DS')]

# %%
# %%sql
# postgresql:///animal_shelters
# Out:
# 'Connected: @animal_shelters'

# %%
# %%sql
# postgresql:///animal_shelters
#     with full_table as (
#     with animals as(
#     select *,
#     cast((extract(year from age(date('2021-12-31'),
#                                 date(birthdate)))) as integer) as age,
#     case when animaltype='Dog' and weight<=10 then 'DS'
#     when animaltype='Dog' and weight<=30 then 'DM'
#     when animaltype='Dog' and weight>30 then 'DL'
#     when animaltype='Cat' and weight<=5 then 'CS'
#     when animaltype='Cat' and weight<=7 then 'CM'
#     when animaltype='Cat' and weight>7 then 'CL'
#     when animaltype='Bird' and weight<=0.7 then 'BS'
#     when animaltype='Bird' and weight<=1.1 then 'BM'
#     else 'BL' end as sizeid
#     from animals as a),
#
#     age_costs as (
#     select cast(age as integer) as age,
#         cast(costs as integer) as cost
#     from age_costs
#     ),
#
#     size_costs as (
#     select sizeid,
#         size,
#         cast(costs as integer) as scosts
#     from size_costs
#     ),
#
#     location_costs as (
#     select location,
#         cast(costs as integer) as lcosts
#     from location_costs
#     )
#
#
#
#
#     select *,
#     (lcosts+scosts+cost) as total
#     from animals
#     left join location_costs as l
#     on animals.location=l.location
#     left join age_costs
#     on animals.age=age_costs.age
#     left join size_costs as s
#     on animals.sizeid=s.sizeid)
#
#     select animaltype,size,
#     sum(total) as total,
#     sum(full_table.total)
#     from full_table
#     group by animaltype,size
# Out:
# 9 rows affected.
# [('Bird', 'Large', 9325, 9325),
#  ('Bird', 'Medium', 4345, 4345),
#  ('Bird', 'Small', 1825, 1825),
#  ('Cat', 'Large', 540295, 540295),
#  ('Cat', 'Medium', 305130, 305130),
#  ('Cat', 'Small', 631130, 631130),
#  ('Dog', 'Large', 1198655, 1198655),
#  ('Dog', 'Medium', 1143435, 1143435),
#  ('Dog', 'Small', 405770, 405770)]

# %%
# %%sql
# postgresql:///animal_shelters
#     with full_table as (
#     with animals as(
#     select *,
#     cast((extract(year from age(date('2021-12-31'),
#                                 date(birthdate)))) as integer) as age,
#     case when animaltype='Dog' and weight<=10 then 'DS'
#     when animaltype='Dog' and weight<=30 then 'DM'
#     when animaltype='Dog' and weight>30 then 'DL'
#     when animaltype='Cat' and weight<=5 then 'CS'
#     when animaltype='Cat' and weight<=7 then 'CM'
#     when animaltype='Cat' and weight>7 then 'CL'
#     when animaltype='Bird' and weight<=0.7 then 'BS'
#     when animaltype='Bird' and weight<=1.1 then 'BM'
#     else 'BL' end as sizeid
#     from animals as a),
#
#     age_costs as (
#     select cast(age as integer) as age,
#         cast(costs as integer) as cost
#     from age_costs
#     ),
#
#     size_costs as (
#     select sizeid,
#         size,
#         cast(costs as integer) as scosts
#     from size_costs
#     ),
#
#     location_costs as (
#     select location,
#         cast(costs as integer) as lcosts
#     from location_costs
#     )
#
#
#
#
#     select *,
#     (lcosts+scosts+cost) as total
#     from animals
#     left join location_costs as l
#     on animals.location=l.location
#     left join age_costs
#     on animals.age=age_costs.age
#     left join size_costs as s
#     on animals.sizeid=s.sizeid),
#
#     total_cost as(
#         with ddd as (select *,
#     extract(year from age(date('2021-12-31'),date(birthdate))) as age,
#     case when animaltype='Dog' and weight<=10 then 'DS'
#     when animaltype='Dog' and weight<=30 then 'DM'
#     when animaltype='Dog' and weight>30 then 'DL'
#     when animaltype='Cat' and weight<=5 then 'CS'
#     when animaltype='Cat' and weight<=7 then 'CM'
#     when animaltype='Cat' and weight>7 then 'CL'
#     when animaltype='Bird' and weight<=0.7 then 'BS'
#     when animaltype='Bird' and weight<=1.1 then 'BM'
#     else 'BL' end as sizeid
#
#     from animals as a
#     left join location_costs as l
#     on a.location=l.location
#
#
#     where animalid not in (select sponsorid from sponsored_animals))
#
#     select sum(costs)
#     from ddd)
#
#     select animaltype,size,
#     sum(total) as total
#     from full_table
#     group by animaltype,size
# Out:
# 9 rows affected.
# [('Cat', 'Small', 631130),
#  ('Cat', 'Large', 540295),
#  ('Cat', 'Medium', 305130),
#  ('Dog', 'Small', 405770),
#  ('Bird', 'Small', 1825),
#  ('Dog', 'Large', 1198655),
#  ('Bird', 'Medium', 4345),
#  ('Bird', 'Large', 9325),
#  ('Dog', 'Medium', 1143435)]

# %%
# %%sql
# postgresql:///animal_shelters
#
#     select animaltype, size, total,total/100
#     from
#     (with full_table as (
#     with animals as(
#     select *,
#     cast((extract(year from age(date('2021-12-31'),
#                                 date(birthdate)))) as integer) as age,
#     case when animaltype='Dog' and weight<=10 then 'DS'
#     when animaltype='Dog' and weight<=30 then 'DM'
#     when animaltype='Dog' and weight>30 then 'DL'
#     when animaltype='Cat' and weight<=5 then 'CS'
#     when animaltype='Cat' and weight<=7 then 'CM'
#     when animaltype='Cat' and weight>7 then 'CL'
#     when animaltype='Bird' and weight<=0.7 then 'BS'
#     when animaltype='Bird' and weight<=1.1 then 'BM'
#     else 'BL' end as sizeid
#     from animals as a),
#
#     age_costs as (
#     select cast(age as integer) as age,
#         cast(costs as integer) as cost
#     from age_costs
#     ),
#
#     size_costs as (
#     select sizeid,
#         size,
#         cast(costs as integer) as scosts
#     from size_costs
#     ),
#
#     location_costs as (
#     select location,
#         cast(costs as integer) as lcosts
#     from location_costs
#     )
#
#
#
#
#     select *,
#     (lcosts+scosts+cost) as total
#     from animals
#     left join location_costs as l
#     on animals.location=l.location
#     left join age_costs
#     on animals.age=age_costs.age
#     left join size_costs as s
#     on animals.sizeid=s.sizeid)
#
#     select animaltype,size,
#     sum(total) as total
#     from full_table
#     group by animaltype,size)
# Out:
# (psycopg2.errors.SyntaxError) subquery in FROM must have an alias
# LINE 3:     (with full_table as (
#             ^
# HINT:  For example, FROM (SELECT ...) [AS] foo.
#
# [SQL: select animaltype, size, total,total/100
#     from
#     (with full_table as (
#     with animals as(
#     select *,
#     cast((extract(year from age(date('2021-12-31'),
#                                 date(birthdate)))) as integer) as age,
#     case when animaltype='Dog' and weight<=10 then 'DS'
#     when animaltype='Dog' and weight<=30 then 'DM'
#     when animaltype='Dog' and weight>30 then 'DL'
#     when animaltype='Cat' and weight<=5 then 'CS'
#     when animaltype='Cat' and weight<=7 then 'CM'
#     when animaltype='Cat' and weight>7 then 'CL'
#     when animaltype='Bird' and weight<=0.7 then 'BS'
#     when animaltype='Bird' and weight<=1.1 then 'BM'
#     else 'BL' end as sizeid
#     from animals as a),
#
#     age_costs as (
#     select cast(age as integer) as age,
#         cast(costs as integer) as cost
#     from age_costs
#     ),
#
#     size_costs as (
#     select sizeid,
#         size,
#         cast(costs as integer) as scosts
#     from size_costs
#     ),
#
#     location_costs as (
#     select location,
#         cast(costs as integer) as lcosts
#     from location_costs
#     )
#
#
#
#
#     select *,
#     (lcosts+scosts+cost) as total
#     from animals
#     left join location_costs as l
#     on animals.location=l.location
#     left join age_costs
#     on animals.age=age_costs.age
#     left join size_costs as s
#     on animals.sizeid=s.sizeid)
#
#     select animaltype,size,
#     sum(total) as total
#     from full_table
#     group by animaltype,size)]
# (Background on this error at: http://sqlalche.me/e/14/f405)

# %%
# %%sql
# postgresql:///animal_shelters
#
#     select *
#     from size_costs
# Out:
# 9 rows affected.
# [('DL', 'Dog', 'Large', 175),
#  ('DM', 'Dog', 'Medium', 150),
#  ('DS', 'Dog', 'Small', 125),
#  ('CL', 'Cat', 'Large', 140),
#  ('CM', 'Cat', 'Medium', 120),
#  ('CS', 'Cat', 'Small', 100),
#  ('BL', 'Bird', 'Large', 110),
#  ('BM', 'Bird', 'Medium', 90),
#  ('BS', 'Bird', 'Small', 70)]

# %%
# %%sql
# postgresql:///animal_shelters
#     with animals as(
#     select *,
#     cast((extract(year from age(date('2021-12-31'),
#                                 date(birthdate)))) as integer) as age,
#     case when animaltype='Dog' and weight<=10 then 'DS'
#     when animaltype='Dog' and weight<=30 then 'DM'
#     when animaltype='Dog' and weight>30 then 'DL'
#     when animaltype='Cat' and weight<=5 then 'CS'
#     when animaltype='Cat' and weight<=7 then 'CM'
#     when animaltype='Cat' and weight>7 then 'CL'
#     when animaltype='Bird' and weight<=0.7 then 'BS'
#     when animaltype='Bird' and weight<=1.1 then 'BM'
#     else 'BL' end as sizeid
#     from animals as a),
#
#     age_costs as (
#     select cast(age as integer) as age,
#         cast(costs as integer) as cost
#     from age_costs
#     ),
#
#     size_costs as (
#     select sizeid,
#         cast(costs as integer) as scosts
#     from size_costs
#     ),
#
#     location_costs as (
#     select location,
#         cast(costs as integer) as lcosts
#     from location_costs
#     )
#
#
#
#
#     select *
#     from animals
#
#     left join location_costs as l
#     on animals.location=l.location
#     left join age_costs
#     on animals.age=age_costs.age
#     left join size_costs as s
#     on animals.sizeid=s.sizeid
#
#
#     limit 5
# Out:
# 5 rows affected.
# [('80066a4b41ac06', '05/11/2019', 'Cat', 'Blue Tabby/White', Decimal('4.0'), 'Fort Worth', 2, 'CS', 'Fort Worth', 100, 2, 0, 'CS', 100),
#  ('968bf2e7230d2f', '11/12/2012', 'Cat', 'Torbie', Decimal('7.0'), 'Houston', 9, 'CM', 'Houston', 140, 9, 150, 'CM', 120),
#  ('8aacfe19c56b0f', '07/08/2013', 'Dog', 'White/Tan', Decimal('45.0'), 'Austin', 8, 'DL', 'Austin', 135, 8, 150, 'DL', 175),
#  ('7126d96889803f', '04/05/2015', 'Cat', 'Black', Decimal('3.0'), 'Houston', 6, 'CS', 'Houston', 140, 6, 100, 'CS', 100),
#  ('9617240ad5b268', '04/29/2014', 'Cat', 'Black', Decimal('9.0'), 'Houston', 7, 'CL', 'Houston', 140, 7, 100, 'CL', 140)]

# %% [markdown]
# # START OVER

# %%
# %%sql
# postgresql:///animal_shelters
#     select animalid,table1.animaltype,size,
#             (age_costs.costs+location_costs.costs+size_costs.costs) as total
#             from (select animalid,animaltype,location,
#                 cast((extract(year from age(date('2021-12-31'),
#                                             date(birthdate)))) as integer) as age,
#                 case when animaltype='Dog' and weight<=10 then 'DS'
#                 when animaltype='Dog' and weight<=30 then 'DM'
#                 when animaltype='Dog' and weight>30 then 'DL'
#                 when animaltype='Cat' and weight<=5 then 'CS'
#                 when animaltype='Cat' and weight<=7 then 'CM'
#                 when animaltype='Cat' and weight>7 then 'CL'
#                 when animaltype='Bird' and weight<=0.7 then 'BS'
#                 when animaltype='Bird' and weight<=1.1 then 'BM'
#                 else 'BL' end as sizeid
#                 from animals)
#             as table1
#             left join location_costs on location_costs.location=table1.location
#             left join size_costs on size_costs.sizeid=table1.sizeid
#             left join (select cast(age as integer),costs from age_costs) as age_costs
#             on age_costs.age=table1.age
#             where animalid not in (select sponsorid from sponsored_animals)
# Out:
# 9757 rows affected.
# [('968bf2e7230d2f', 'Cat', 'Medium', 410),
#  ('8aacfe19c56b0f', 'Dog', 'Large', 460),
#  ('9617240ad5b268', 'Cat', 'Large', 380),
#  ('fd7bf1fa986957', 'Dog', 'Large', 310),
#  ('691081c83b1075', 'Dog', 'Small', 325),
#  ('f957d0fabf9e63', 'Dog', 'Medium', 250),
#  ('2f17d474be934d', 'Dog', 'Medium', 285),
#  ('e03a24b436f6db', 'Dog', 'Medium', 440),
#  ('fd8befa64f05ff', 'Cat', 'Large', 280),
#  ('b8f7754e09af92', 'Cat', 'Small', 235),
#  ('ed2978cd5bca69', 'Dog', 'Medium', 270),
#  ('8fe65f7a703ade', 'Dog', 'Small', 385),
#  ('9198f5e5e2b32c', 'Cat', 'Small', 320),
#  ('29742f716a301a', 'Cat', 'Small', 210),
#  ('bb1cd9438679b9', 'Dog', 'Large', 425),
#  ('8c7eee119f7f16', 'Cat', 'Small', 300),
#  ('e82a5937e6958c', 'Dog', 'Large', 395),
#  ('3e86b596b8f94a', 'Dog', 'Medium', 435),
#  ('c47b50c3868715', 'Dog', 'Large', 460),
#  ('5ef4a5f2b06b50', 'Dog', 'Medium', 385),
#  ('9c6cbeb11aaabc', 'Dog', 'Medium', 490),
#  ('4cc9a2d6557b4f', 'Cat', 'Small', 240),
#  ('4a9d89bd1378ec', 'Dog', 'Large', 310),
#  ('4f46d36ab99548', 'Cat', 'Large', 260),
#  ('d8e7b3880035c4', 'Dog', 'Large', 385),
#  ('4b0cf80d2eabc6', 'Dog', 'Medium', 370),
#  ('16e73c9bdb6569', 'Cat', 'Large', 375),
#  ('03186fdb951871', 'Dog', 'Small', 365),
#  ('1504374bd359c1', 'Dog', 'Medium', 250),
#  ('f0304878e79ba0', 'Dog', 'Small', 360),
#  ('203ae63390f5f7', 'Dog', 'Large', 295),
#  ('29e5db0f4ac30e', 'Dog', 'Small', 410),
#  ('ad1faa45954f75', 'Dog', 'Large', 425),
#  ('43fe85cc3aae6d', 'Cat', 'Medium', 405),
#  ('adc580f3beaa23', 'Cat', 'Small', 235),
#  ('e1a93c5a176410', 'Cat', 'Small', 335),
#  ('d0cfb2a403e9f7', 'Cat', 'Large', 380),
#  ('f143df80a0e85b', 'Cat', 'Large', 250),
#  ('153ddefeef4fa5', 'Cat', 'Small', 235),
#  ('a3261e994375c0', 'Dog', 'Small', 235),
#  ('a5a0dd7d7258e5', 'Cat', 'Small', 320),
#  ('b0ba9ef5baa777', 'Dog', 'Large', 425),
#  ('413e631561b302', 'Cat', 'Small', 360),
#  ('a7602e5682669f', 'Cat', 'Large', 360),
#  ('8eb835f2103fc1', 'Dog', 'Large', 435),
#  ('ed4e9638d6b617', 'Cat', 'Small', 210),
#  ('a4a1f5bdfa6465', 'Cat', 'Medium', 355),
#  ('5678c093e52001', 'Dog', 'Small', 265),
#  ('fb2382b5775326', 'Dog', 'Large', 275),
#  ('991ed32abec314', 'Dog', 'Large', 395),
#  ('f79c9cac3be408', 'Cat', 'Large', 275),
#  ('59788fb4dac9a1', 'Dog', 'Large', 310),
#  ('ee352aa3a6455a', 'Cat', 'Medium', 390),
#  ('c0c9d1f3abf4a2', 'Cat', 'Small', 435),
#  ('5ba246dfdca11f', 'Dog', 'Medium', 460),
#  ('64fe4c41d314e4', 'Cat', 'Small', 310),
#  ('10055b87a6aa2c', 'Cat', 'Large', 240),
#  ('17e6ead5447443', 'Dog', 'Medium', 270),
#  ('c2147c310d3c26', 'Dog', 'Large', 610),
#  ('f3d400db00c33c', 'Cat', 'Large', 350),
#  ('1b29299a99df7a', 'Cat', 'Large', 375),
#  ('d5bf9111156ca9', 'Dog', 'Medium', 460),
#  ('42bb8a2146f822', 'Dog', 'Medium', 435),
#  ('7f0b85fd6408a0', 'Cat', 'Medium', 340),
#  ('b357b8d3123d3d', 'Cat', 'Large', 375),
#  ('188c231dac1488', 'Cat', 'Small', 335),
#  ('df97d004a10b5f', 'Cat', 'Small', 370),
#  ('0433e1738ac07b', 'Cat', 'Large', 280),
#  ('c3726c586eddae', 'Cat', 'Small', 350),
#  ('ae4a90a9c2075c', 'Dog', 'Large', 310),
#  ('904b509337eb47', 'Cat', 'Small', 220),
#  ('04e8b8667a5c9d', 'Cat', 'Medium', 405),
#  ('1de7b5d80255bc', 'Dog', 'Medium', 590),
#  ('28ffd81b8e54be', 'Dog', 'Large', 285),
#  ('49f0d3c4f21df7', 'Dog', 'Medium', 260),
#  ('cd304596b8ba83', 'Dog', 'Small', 245),
#  ('dcaaa8ba643f7a', 'Cat', 'Small', 335),
#  ('8e1cbc5b532625', 'Dog', 'Medium', 435),
#  ('e9b2b1e0dec7a5', 'Dog', 'Small', 260),
#  ('7e5e4307996df2', 'Cat', 'Large', 260),
#  ('9d34bd3ff50fd7', 'Dog', 'Medium', 370),
#  ('c28f14c9928d83', 'Dog', 'Medium', 385),
#  ('5035e3b2762a1a', 'Dog', 'Large', 415),
#  ('e8dd41a7f33267', 'Cat', 'Small', 310),
#  ('e1a06407d832c5', 'Cat', 'Small', 370),
#  ('ca27e328adec90', 'Dog', 'Small', 415),
#  ('af46bde1898f1f', 'Cat', 'Small', 240),
#  ('422031dd406c85', 'Cat', 'Large', 425),
#  ('10e4de5253cd45', 'Cat', 'Small', 340),
#  ('346f914fbe622f', 'Cat', 'Medium', 410),
#  ('8974702ea02652', 'Cat', 'Large', 275),
#  ('87801a4287c51b', 'Cat', 'Medium', 240),
#  ('1e282b68285da4', 'Dog', 'Medium', 420),
#  ('8f6c2b5dc4cb28', 'Cat', 'Small', 340),
#  ('4920dced24cede', 'Cat', 'Medium', 330),
#  ('2bce83bdaba698', 'Dog', 'Medium', 385),
#  ('4eda1161b2f96c', 'Dog', 'Large', 295),
#  ('85b602a171b5e8', 'Cat', 'Small', 300),
#  ('5733fcdd0d2a00', 'Dog', 'Small', 245),
#  ('73d117de93c28a', 'Cat', 'Small', 320),
#  ('1721df19a788a9', 'Cat', 'Large', 350),
#  ('a5d9accc1bcac2', 'Dog', 'Large', 275),
#  ('53d47791131e32', 'Cat', 'Large', 360),
#  ('e0bd1e3e55145b', 'Dog', 'Large', 415),
#  ('4eefcf6ed3db93', 'Dog', 'Medium', 270),
#  ('fe75c82e06c823', 'Dog', 'Small', 415),
#  ('f956ccf20c0766', 'Cat', 'Small', 350),
#  ('2aa548af5222ee', 'Cat', 'Large', 430),
#  ('0a172119f94fe3', 'Cat', 'Small', 300),
#  ('a9507b8d1acbbd', 'Dog', 'Large', 465),
#  ('6e5313035185a0', 'Dog', 'Medium', 410),
#  ('2f6da3da1451b4', 'Dog', 'Medium', 390),
#  ('e4c45da5de6f7b', 'Dog', 'Medium', 370),
#  ('148631eae1989f', 'Cat', 'Small', 235),
#  ('fc2b01b3809c25', 'Dog', 'Large', 425),
#  ('2d7d9146b1281e', 'Cat', 'Large', 430),
#  ('5e48fb44040f64', 'Dog', 'Medium', 450),
#  ('d8993031cbadf0', 'Dog', 'Large', 410),
#  ('4ffef53db23295', 'Dog', 'Medium', 270),
#  ('bffdd7dabdf7b8', 'Dog', 'Medium', 440),
#  ('bc4b2b68962f5e', 'Dog', 'Medium', 485),
#  ('8396b1a647fd59', 'Dog', 'Medium', 350),
#  ('58e7c0ff234743', 'Dog', 'Large', 275),
#  ('cfc9bb534729e2', 'Cat', 'Small', 220),
#  ('615908186a0e1d', 'Dog', 'Medium', 585),
#  ('8ed8642a08523b', 'Dog', 'Large', 310),
#  ('170445de11d689', 'Dog', 'Medium', 360),
#  ('35e7a32dccc8a0', 'Cat', 'Small', 235),
#  ('e5e6abd0ab0ebe', 'Dog', 'Medium', 260),
#  ('966112a86af351', 'Cat', 'Small', 385),
#  ('e913c35f7c3a6f', 'Dog', 'Large', 445),
#  ('d41adfbf45f426', 'Dog', 'Large', 295),
#  ('5a87697178bb5f', 'Cat', 'Large', 375),
#  ('be744f2f8a6196', 'Dog', 'Medium', 360),
#  ('79fa29dee7c97d', 'Dog', 'Medium', 285),
#  ('eaa9abc216ec6a', 'Cat', 'Large', 260),
#  ('caf04a6ac740f6', 'Dog', 'Large', 395),
#  ('26ee655bdfd3c3', 'Dog', 'Large', 465),
#  ('e55da869a3b47f', 'Dog', 'Medium', 290),
#  ('9a1d11489181a7', 'Cat', 'Large', 275),
#  ('b8c7fffb259801', 'Cat', 'Small', 220),
#  ('cee66d4d7b358b', 'Dog', 'Small', 560),
#  ('f4cc11df83855e', 'Dog', 'Large', 415),
#  ('3364f9e60f023e', 'Dog', 'Large', 410),
#  ('a1a4159214c0e9', 'Dog', 'Large', 465),
#  ('c0b9fc5322ef26', 'Dog', 'Medium', 370),
#  ('214c71ad4f1b9c', 'Cat', 'Medium', 255),
#  ('e5521623d73bc4', 'Cat', 'Large', 275),
#  ('b539aa63383a70', 'Dog', 'Large', 395),
#  ('77f3ede3da14e0', 'Dog', 'Small', 375),
#  ('3a1d12a2e189c2', 'Dog', 'Medium', 250),
#  ('d62ebec619405b', 'Cat', 'Large', 380),
#  ('e8a43511baff1e', 'Dog', 'Large', 575),
#  ('d716d3538afc3a', 'Dog', 'Medium', 350),
#  ('ccb6294c250f60', 'Cat', 'Small', 200),
#  ('f1ab6603fafeec', 'Cat', 'Small', 320),
#  ('6dd0447e9d068e', 'Dog', 'Medium', 440),
#  ('ec6cd633070abf', 'Dog', 'Medium', 350),
#  ('98e9315663198a', 'Dog', 'Medium', 390),
#  ('96f9430a5884cb', 'Dog', 'Medium', 260),
#  ('4da93e4671870c', 'Cat', 'Medium', 355),
#  ('85615acabba449', 'Dog', 'Large', 310),
#  ('9d8ef194fccdad', 'Cat', 'Small', 320),
#  ('708ccb534ef4f2', 'Dog', 'Small', 365),
#  ('c3e55db57f3926', 'Dog', 'Large', 310),
#  ('3202ca2682776c', 'Dog', 'Small', 375),
#  ('0aca63de48e1d1', 'Dog', 'Medium', 285),
#  ('e276133a4c37d8', 'Cat', 'Small', 340),
#  ('2c5f9cc9d08c8e', 'Dog', 'Medium', 390),
#  ('6bd31c0c7c292c', 'Cat', 'Small', 320),
#  ('457bbe4f933737', 'Cat', 'Small', 310),
#  ('f45a9c679af23c', 'Dog', 'Large', 410),
#  ('b043fe5f9d5ca6', 'Cat', 'Medium', 255),
#  ('924a051f96face', 'Dog', 'Medium', 250),
#  ('8e548106af9f1b', 'Dog', 'Medium', 485),
#  ('dda6c0675fee09', 'Cat', 'Small', 435),
#  ('13eb10204dd7c0', 'Dog', 'Large', 465),
#  ('14cda98a845174', 'Dog', 'Medium', 400),
#  ('2dbeae0b558cd2', 'Dog', 'Medium', 370),
#  ('b871e4d615de47', 'Dog', 'Large', 395),
#  ('e1dbf11e170bbc', 'Cat', 'Small', 335),
#  ('c5a6c78bae269c', 'Bird', 'Large', 330),
#  ('fc16c559ea1271', 'Dog', 'Large', 285),
#  ('be4f77168d50f9', 'Dog', 'Medium', 570),
#  ('3268d26040595b', 'Cat', 'Large', 240),
#  ('9b4c50480d7a3e', 'Dog', 'Large', 385),
#  ('721652362af0b7', 'Dog', 'Large', 375),
#  ('e53d68dc56490e', 'Cat', 'Small', 390),
#  ('fd91870d819f54', 'Cat', 'Medium', 460),
#  ('6440e1424a6927', 'Dog', 'Medium', 435),
#  ('f148cb036a03d0', 'Cat', 'Large', 350),
#  ('754e81a8720336', 'Cat', 'Large', 340),
#  ('ebaa6777f3b00f', 'Dog', 'Medium', 285),
#  ('ca5fd379e13e83', 'Dog', 'Small', 415),
#  ('6fefae8f9c6f52', 'Cat', 'Large', 340),
#  ('0055763ba7afd9', 'Dog', 'Large', 445),
#  ('d08026a56b9ecb', 'Dog', 'Medium', 435),
#  ('da6dbbe378abc8', 'Dog', 'Large', 465),
#  ('dc78e484ec5d9a', 'Dog', 'Medium', 440),
#  ('de629316935f8f', 'Dog', 'Large', 460),
#  ('edd6f582899526', 'Cat', 'Large', 350),
#  ('3487d63d1c995d', 'Cat', 'Medium', 405),
#  ('c8d56792473a55', 'Dog', 'Medium', 290),
#  ('9e1a1cd0cf61f5', 'Dog', 'Large', 425),
#  ('c2f01a954d18ea', 'Dog', 'Medium', 250),
#  ('485b4ca08f4395', 'Dog', 'Large', 295),
#  ('8673fb1d066b15', 'Cat', 'Medium', 360),
#  ('a2e8209d944a75', 'Cat', 'Small', 340),
#  ('4195d23d06f5fa', 'Dog', 'Large', 295),
#  ('7d23cb280b3588', 'Cat', 'Large', 375),
#  ('5c94737110dbf0', 'Dog', 'Medium', 420),
#  ('6f652d47d87140', 'Dog', 'Medium', 400),
#  ('624972bb3149e0', 'Dog', 'Small', 335),
#  ('56a863c00b1965', 'Dog', 'Medium', 435),
#  ('9c4e6c12453443', 'Dog', 'Small', 465),
#  ('1fa41c1992c021', 'Cat', 'Small', 335),
#  ('78d4c7a032037a', 'Cat', 'Medium', 255),
#  ('e295e2e874532f', 'Dog', 'Medium', 250),
#  ('0fac35eb6f8512', 'Dog', 'Medium', 360),
#  ('ac3efd6a82e3ac', 'Cat', 'Small', 340),
#  ('37bf3dc146715f', 'Cat', 'Large', 430),
#  ('27dbe758155240', 'Cat', 'Small', 310),
#  ('23aa55f0e8050b', 'Dog', 'Medium', 385),
#  ('48b52789edafe9', 'Dog', 'Medium', 290),
#  ('cada423027df8b', 'Dog', 'Large', 460),
#  ('fa563a509c0e6b', 'Dog', 'Large', 515),
#  ('3c685a4c6139c4', 'Dog', 'Medium', 260),
#  ('863740dc8613d4', 'Dog', 'Large', 375),
#  ('8ae1480648c55c', 'Dog', 'Medium', 385),
#  ('77c2335b1b548a', 'Cat', 'Small', 200),
#  ('c719953563e400', 'Cat', 'Small', 335),
#  ('43bee409c3d7df', 'Dog', 'Medium', 385),
#  ('f9172b46ecc0ba', 'Cat', 'Small', 340),
#  ('143898b081a79e', 'Dog', 'Medium', 440),
#  ('c533df71c445b4', 'Cat', 'Medium', 230),
#  ('d8dfb569f74de8', 'Dog', 'Medium', 385),
#  ('2a924b7cc14829', 'Dog', 'Small', 360),
#  ('8daffd35452ce5', 'Dog', 'Large', 410),
#  ('d434704016d1c7', 'Dog', 'Medium', 370),
#  ('328af9d6cb19d8', 'Dog', 'Large', 460),
#  ('d0589c4a93b79c', 'Dog', 'Medium', 435),
#  ('7f9d23fdd03282', 'Cat', 'Medium', 370),
#  ('df409ef77af2ab', 'Dog', 'Medium', 485),
#  ('bec6392753c2cb', 'Dog', 'Small', 415),
#  ('5a78f5011912b3', 'Dog', 'Large', 410),
#  ('98f5d43d99903d', 'Dog', 'Medium', 440),
#  ('9654ec395cff97', 'Cat', 'Small', 240),
#  ('15470e8e93d813', 'Dog', 'Small', 415),
#  ('43cca4ec9490a2', 'Dog', 'Medium', 270),
#  ('6d1b421a5aa4a9', 'Cat', 'Small', 300),
#  ('3ae44be39c2f9c', 'Dog', 'Small', 445),
#  ('98e12a1ba07801', 'Dog', 'Medium', 285),
#  ('ef3e53dfeaac22', 'Dog', 'Medium', 360),
#  ('50e1e7a58f0132', 'Cat', 'Medium', 230),
#  ('376d7a1ac24bc8', 'Dog', 'Medium', 270),
#  ('76cdf30ae3ab7b', 'Dog', 'Large', 385),
#  ('1e359e395490c3', 'Cat', 'Small', 335),
#  ('870ae64f2bdf6b', 'Cat', 'Small', 300),
#  ('68287884457c2c', 'Dog', 'Small', 260),
#  ('34485abb7a1f48', 'Dog', 'Large', 275),
#  ('74afb6a7513cbf', 'Dog', 'Large', 415),
#  ('c8636f796debef', 'Cat', 'Large', 390),
#  ('e7d2481890e2e5', 'Dog', 'Large', 310),
#  ('7321133911af1d', 'Dog', 'Medium', 390),
#  ('af3a2d0f19dcfd', 'Dog', 'Small', 345),
#  ('b3ac46307977f2', 'Cat', 'Large', 440),
#  ('1e3fa73412ccbe', 'Dog', 'Medium', 435),
#  ('c432ef16845c98', 'Dog', 'Large', 510),
#  ('0004f63e21c285', 'Dog', 'Medium', 590),
#  ('71b7e4d4c59d79', 'Dog', 'Small', 415),
#  ('d3417641581534', 'Dog', 'Small', 235),
#  ('674f94dcfa1c2e', 'Cat', 'Medium', 330),
#  ('92a47d52c25418', 'Dog', 'Large', 310),
#  ('582c51a99e0b50', 'Cat', 'Large', 430),
#  ('8e385ccb99f8e0', 'Cat', 'Large', 410),
#  ('922ee6785a16d1', 'Cat', 'Small', 210),
#  ('5f1b55301deb9a', 'Cat', 'Small', 210),
#  ('4d03de1701144e', 'Dog', 'Medium', 290),
#  ('4d30e8ea0325ff', 'Cat', 'Large', 275),
#  ('32e3dae35d8b1b', 'Dog', 'Medium', 420),
#  ('a0b61b2786fe0c', 'Dog', 'Large', 395),
#  ('79e6cc2c5cdd74', 'Dog', 'Medium', 260),
#  ('628322f39ab630', 'Cat', 'Large', 375),
#  ('beb49b14a9b661', 'Dog', 'Medium', 350),
#  ('4a1aa203d62e80', 'Dog', 'Large', 465),
#  ('6a5b6dcad0c333', 'Dog', 'Medium', 270),
#  ('7023fea16d5e39', 'Cat', 'Large', 425),
#  ('dcc75ce6a60e6f', 'Dog', 'Small', 425),
#  ('de7a016c3dc963', 'Cat', 'Small', 340),
#  ('5858a6b121757a', 'Dog', 'Large', 310),
#  ('a0dc09e7742b1e', 'Dog', 'Medium', 435),
#  ('5e84cc7b062ae0', 'Dog', 'Large', 460),
#  ('e4ba52130f15ac', 'Cat', 'Medium', 360),
#  ('36987c085bde65', 'Dog', 'Large', 485),
#  ('ca6b3cc9497e6d', 'Dog', 'Medium', 485),
#  ('9e52020e7aa6d7', 'Dog', 'Large', 445),
#  ('5d0ef4c180d027', 'Dog', 'Large', 395),
#  ('6eeeb96af18ab0', 'Dog', 'Large', 375),
#  ('e66f0b7e9f17a6', 'Cat', 'Medium', 370),
#  ('ffeee03b856496', 'Dog', 'Medium', 385),
#  ('707b3ccb5adb6c', 'Dog', 'Medium', 350),
#  ('0e7ce6528d3ca7', 'Cat', 'Medium', 220),
#  ('d7f6b72f07645c', 'Cat', 'Small', 235),
#  ('0b62fefdd91f38', 'Dog', 'Medium', 420),
#  ('7ba56410400895', 'Dog', 'Large', 445),
#  ('95aa0a7ebbbd3e', 'Dog', 'Large', 515),
#  ('5022eb62c37910', 'Dog', 'Medium', 440),
#  ('fab3bc363ff09e', 'Cat', 'Small', 240),
#  ('5c810a8c474243', 'Cat', 'Small', 235),
#  ('766a895e8fc9ee', 'Dog', 'Medium', 420),
#  ('3a746c8d476ff3', 'Cat', 'Small', 235),
#  ('e87dd95dc25a9b', 'Dog', 'Small', 325),
#  ('63ae17572262ce', 'Dog', 'Medium', 420),
#  ('4739b7e6f05e69', 'Dog', 'Large', 460),
#  ('d8dbe9ed5a8cb3', 'Dog', 'Large', 395),
#  ('92b740e3af680b', 'Cat', 'Large', 360),
#  ('b43b7837c13cd3', 'Dog', 'Medium', 285),
#  ('83e67e5fb7ff96', 'Dog', 'Large', 395),
#  ('baed0ef2c82d92', 'Dog', 'Medium', 385),
#  ('f8157ede176909', 'Dog', 'Large', 465),
#  ('53b8d74147f6db', 'Dog', 'Large', 375),
#  ('15848fe8d2c665', 'Dog', 'Small', 395),
#  ('08c6a14baae1f9', 'Dog', 'Medium', 390),
#  ('1677f4774372d0', 'Cat', 'Small', 200),
#  ('302c31e17796f2', 'Dog', 'Large', 375),
#  ('cfe51fee10142b', 'Dog', 'Small', 365),
#  ('4f62b6b7ab75dd', 'Cat', 'Large', 375),
#  ('14bc378d97fb96', 'Dog', 'Medium', 370),
#  ('bb613aff5f428f', 'Dog', 'Small', 385),
#  ('b6792fbaf8dc4e', 'Dog', 'Medium', 290),
#  ('afdd1e3cbf5ece', 'Dog', 'Medium', 285),
#  ('c40bc14e0c9e75', 'Dog', 'Small', 395),
#  ('b87bc713a9eba8', 'Dog', 'Large', 395),
#  ('feb9f89771d372', 'Dog', 'Large', 410),
#  ('ea89ab58bfd2a1', 'Dog', 'Large', 425),
#  ('b71d507f603386', 'Cat', 'Small', 300),
#  ('1f8ad2aefcd081', 'Dog', 'Medium', 440),
#  ('8ecd946b89249a', 'Dog', 'Medium', 285),
#  ('11c4a7b7c17e3e', 'Cat', 'Medium', 340),
#  ('7ec09f2a93f452', 'Dog', 'Medium', 370),
#  ('a244dddcf19b32', 'Dog', 'Medium', 435),
#  ('8fb1b55d9e7311', 'Dog', 'Large', 460),
#  ('408be88a3517e7', 'Dog', 'Large', 465),
#  ('03a6891aefb119', 'Dog', 'Medium', 440),
#  ('3938bc2b1b8891', 'Cat', 'Small', 300),
#  ('c57043e17ff90a', 'Cat', 'Medium', 340),
#  ('84818bf9651f3b', 'Cat', 'Medium', 255),
#  ('4111200da64efc', 'Cat', 'Small', 240),
#  ('96de104cc5dfcf', 'Dog', 'Medium', 420),
#  ('f058dd592b3fc5', 'Dog', 'Medium', 385),
#  ('99254ad79723e1', 'Dog', 'Small', 260),
#  ('d0c00b6a37352c', 'Cat', 'Medium', 330),
#  ('a3dc5fe0f61de9', 'Dog', 'Medium', 390),
#  ('4935994bc61f63', 'Dog', 'Medium', 370),
#  ('fddb46dc53663b', 'Dog', 'Small', 345),
#  ('e7df6542b330e8', 'Dog', 'Medium', 420),
#  ('568892d79061ff', 'Dog', 'Medium', 270),
#  ('5c1b35f33deda5', 'Dog', 'Small', 375),
#  ('94b3a6017d8959', 'Cat', 'Small', 240),
#  ('8e1a8dd7486454', 'Dog', 'Medium', 350),
#  ('41e66a8f7ca8b2', 'Dog', 'Large', 415),
#  ('122819d11cb9e1', 'Dog', 'Medium', 590),
#  ('45b3045f6228ea', 'Cat', 'Medium', 240),
#  ('c178e0ddbdbe49', 'Cat', 'Small', 435),
#  ('7c8fd56aea576c', 'Dog', 'Large', 310),
#  ('4b09f6cbaba256', 'Cat', 'Large', 380),
#  ('51dd50dcf413ae', 'Cat', 'Small', 235),
#  ('a18208643b5e5d', 'Dog', 'Medium', 285),
#  ('2e066408400d2f', 'Dog', 'Medium', 360),
#  ('cc8bffc0c3b1de', 'Cat', 'Medium', 370),
#  ('5b813a9212c774', 'Cat', 'Small', 320),
#  ('a99f765c430ce4', 'Dog', 'Medium', 410),
#  ('79e623989b34b5', 'Dog', 'Large', 310),
#  ('89ae0d9dac5422', 'Dog', 'Medium', 285),
#  ('b9622820cb659d', 'Cat', 'Small', 210),
#  ('15c5f937490d2a', 'Dog', 'Small', 260),
#  ('1fd457e1fb2142', 'Cat', 'Small', 235),
#  ('e183161f9bbf8b', 'Dog', 'Medium', 250),
#  ('d0bd7415fecdb2', 'Cat', 'Small', 350),
#  ('de62bc6114c688', 'Dog', 'Large', 395),
#  ('ef4964d2595ea4', 'Cat', 'Small', 210),
#  ('6068c5fae571f8', 'Cat', 'Small', 340),
#  ('69adb6a6964325', 'Dog', 'Medium', 470),
#  ('880cec11106ca2', 'Cat', 'Small', 235),
#  ('b07a67f32d7ce6', 'Dog', 'Large', 445),
#  ('8a0b78ef25fba4', 'Dog', 'Medium', 385),
#  ('75e3dc545638a0', 'Dog', 'Large', 375),
#  ('ea1eb9c710b605', 'Cat', 'Large', 275),
#  ('e3f36fc0295e4a', 'Cat', 'Medium', 330),
#  ('d7ba36d7b70aee', 'Dog', 'Small', 345),
#  ('cf782b24828db1', 'Dog', 'Medium', 270),
#  ('ff9644e3001799', 'Dog', 'Medium', 285),
#  ('fdc220246970a9', 'Dog', 'Medium', 270),
#  ('c0c30a3440d0ae', 'Dog', 'Medium', 260),
#  ('6d9359e4ba26a9', 'Dog', 'Large', 285),
#  ('15334a277b2232', 'Cat', 'Large', 260),
#  ('487459283c0114', 'Dog', 'Small', 375),
#  ('116a5ff66dac09', 'Dog', 'Medium', 250),
#  ('97b4f22ec375ec', 'Dog', 'Large', 310),
#  ('88c359d8ce6856', 'Cat', 'Large', 340),
#  ('348347a3fcb7ee', 'Cat', 'Medium', 220),
#  ('1e7d3db2e8a656', 'Dog', 'Medium', 385),
#  ('594d94717f3e48', 'Dog', 'Medium', 270),
#  ('d67e5800c4c68b', 'Cat', 'Small', 200),
#  ('fa07cd44ab553b', 'Dog', 'Large', 460),
#  ('4ee7aceec469bc', 'Dog', 'Medium', 400),
#  ('4b27b16627f9ce', 'Cat', 'Large', 360),
#  ('095ca38f87a28f', 'Dog', 'Medium', 390),
#  ('6e0d1fef37a10c', 'Dog', 'Large', 395),
#  ('83979a7a871eb7', 'Dog', 'Large', 375),
#  ('f20572168c25a3', 'Dog', 'Small', 375),
#  ('a3da1c6441655a', 'Dog', 'Small', 360),
#  ('ff68c422d341a7', 'Cat', 'Small', 300),
#  ('ca67e04df46148', 'Dog', 'Large', 410),
#  ('a6ec93ca25fd2a', 'Cat', 'Small', 320),
#  ('ee9dcff8e520f1', 'Dog', 'Medium', 285),
#  ('610243437b3789', 'Cat', 'Large', 380),
#  ('a33b5dc2192d9f', 'Dog', 'Large', 445),
#  ('5c33c688c3cd15', 'Dog', 'Small', 360),
#  ('834323cac1fb4a', 'Dog', 'Large', 285),
#  ('db631b68cb4ecb', 'Dog', 'Large', 515),
#  ('565a09e4060bf3', 'Cat', 'Medium', 260),
#  ('d88868f31aaadd', 'Cat', 'Medium', 340),
#  ('92520208c8ab18', 'Dog', 'Large', 445),
#  ('b421bf88510f55', 'Dog', 'Large', 395),
#  ('ac41d9f51bc1e4', 'Cat', 'Medium', 240),
#  ('3bf669ce5e32bd', 'Cat', 'Small', 335),
#  ('977d189a6b8395', 'Cat', 'Medium', 320),
#  ('3828dbbaec17c2', 'Dog', 'Large', 425),
#  ('937465a7922828', 'Dog', 'Small', 375),
#  ('633eddf3473832', 'Dog', 'Large', 310),
#  ('821961ce777edc', 'Cat', 'Large', 390),
#  ('0027bbd1caf1e9', 'Dog', 'Large', 410),
#  ('bf8d8e4c965022', 'Dog', 'Medium', 285),
#  ('d66337e410c895', 'Dog', 'Large', 425),
#  ('999e3dd402ccf3', 'Dog', 'Medium', 485),
#  ('78b37fd84ce35d', 'Cat', 'Medium', 330),
#  ('79094f4b47739b', 'Dog', 'Medium', 400),
#  ('d23e7a8c7c7913', 'Cat', 'Medium', 390),
#  ('7b9a771c2b4a1b', 'Dog', 'Large', 460),
#  ('9cbca3eaf75380', 'Dog', 'Small', 235),
#  ('53c5a6eda67a66', 'Cat', 'Large', 360),
#  ('eaf6fd1669f2ba', 'Cat', 'Small', 300),
#  ('8c90e6a5e20faa', 'Dog', 'Medium', 385),
#  ('e56b795c352bb2', 'Cat', 'Large', 340),
#  ('805d3f77616e06', 'Cat', 'Small', 240),
#  ('66c405dba1a44f', 'Dog', 'Medium', 410),
#  ('a29dde08938b86', 'Dog', 'Large', 445),
#  ('c74f0ad6075579', 'Dog', 'Large', 460),
#  ('2aa0899986554d', 'Cat', 'Small', 235),
#  ('a35835e1401859', 'Dog', 'Medium', 260),
#  ('f70e097b01ee73', 'Dog', 'Large', 310),
#  ('cce6befd6ed40d', 'Dog', 'Large', 575),
#  ('494ecdb01d84e4', 'Dog', 'Medium', 385),
#  ('30aea66ec9f893', 'Dog', 'Medium', 260),
#  ('eabb1655ce9be2', 'Dog', 'Medium', 440),
#  ('e594ce16fd12c0', 'Dog', 'Medium', 440),
#  ('c83738a1a03e73', 'Dog', 'Medium', 560),
#  ('179c2f373b4549', 'Cat', 'Small', 310),
#  ('abeca6d477ef47', 'Dog', 'Large', 575),
#  ('d3c29b4569fa66', 'Dog', 'Large', 295),
#  ('61b36431a1efd2', 'Dog', 'Medium', 250),
#  ('6136d04867c329', 'Cat', 'Small', 340),
#  ('589a208fa2a6d1', 'Dog', 'Large', 310),
#  ('ce30259ad459e5', 'Dog', 'Small', 365),
#  ('4849aad48ab621', 'Cat', 'Small', 370),
#  ('35b1c5777653fd', 'Dog', 'Large', 310),
#  ('41cc7ffe40e419', 'Dog', 'Medium', 385),
#  ('f12eda70bd6029', 'Dog', 'Large', 445),
#  ('e030cd9e5060cc', 'Dog', 'Medium', 435),
#  ('ea7a3d96e5c07b', 'Dog', 'Medium', 250),
#  ('9ce1b5092c2b71', 'Dog', 'Medium', 385),
#  ('c3a1116dc0100b', 'Dog', 'Large', 595),
#  ('9badca1b4e6668', 'Dog', 'Large', 310),
#  ('b43ad91139925f', 'Dog', 'Small', 365),
#  ('c82fdfbe14b420', 'Dog', 'Medium', 420),
#  ('2700d362a40e86', 'Cat', 'Large', 430),
#  ('14702df621319a', 'Cat', 'Large', 350),
#  ('d6f97f316febaf', 'Cat', 'Small', 385),
#  ('b67a78c4108307', 'Dog', 'Large', 310),
#  ('ff9f47d9de8ee1', 'Dog', 'Large', 375),
#  ('390ef953a30c3d', 'Cat', 'Small', 240),
#  ('ffb06f235e032c', 'Cat', 'Small', 310),
#  ('c9ae0d3b2c6594', 'Cat', 'Small', 240),
#  ('37948a6f3c84a9', 'Cat', 'Small', 335),
#  ('9b1050ed667a04', 'Dog', 'Medium', 420),
#  ('867bee2f184124', 'Cat', 'Small', 210),
#  ('0208dc7865b428', 'Dog', 'Small', 395),
#  ('3e57cd0e8ed29f', 'Dog', 'Large', 460),
#  ('526bc92a9c9aed', 'Dog', 'Large', 310),
#  ('885107c7d86bac', 'Cat', 'Small', 320),
#  ('3a3bde17b3fcf1', 'Dog', 'Medium', 385),
#  ('34740732293b4a', 'Dog', 'Medium', 370),
#  ('edfa7b5398ba7e', 'Cat', 'Large', 380),
#  ('7ec3ef35e80aba', 'Cat', 'Small', 385),
#  ('960cbb90c68776', 'Dog', 'Small', 325),
#  ('85bd891f6db330', 'Dog', 'Large', 275),
#  ('43d86b5143d619', 'Dog', 'Small', 265),
#  ('aea4f5cdb79c3e', 'Cat', 'Large', 400),
#  ('045494bc2753ac', 'Cat', 'Large', 275),
#  ('e842bb3ee9ced7', 'Dog', 'Large', 460),
#  ('573fbc5c568c84', 'Dog', 'Medium', 350),
#  ('c04f0c015f9688', 'Cat', 'Large', 240),
#  ('1079a682d0fa31', 'Cat', 'Small', 320),
#  ('887b60515d55b1', 'Dog', 'Large', 465),
#  ('2216cd6aaa21bf', 'Dog', 'Large', 295),
#  ('244f481c9fb0e4', 'Cat', 'Large', 440),
#  ('35984f30d3dba9', 'Dog', 'Small', 385),
#  ('4c9d518d22be7b', 'Dog', 'Large', 310),
#  ('082f6d2206b2f0', 'Cat', 'Small', 210),
#  ('a4172345bf0283', 'Dog', 'Medium', 285),
#  ('8ac9bccea512b6', 'Dog', 'Medium', 410),
#  ('fa6bfc4ad25349', 'Cat', 'Medium', 220),
#  ('d3f0315103d8a5', 'Dog', 'Medium', 410),
#  ('9bfd4cc0ecccf6', 'Dog', 'Medium', 290),
#  ('11a73a88e43332', 'Dog', 'Medium', 590),
#  ('bfa277813d3430', 'Cat', 'Small', 300),
#  ('4af8cfb45ad72b', 'Dog', 'Large', 275),
#  ('eb9ca21d244b3f', 'Dog', 'Small', 385),
#  ('08c44b4a29f905', 'Cat', 'Small', 340),
#  ('a05a70b6a15725', 'Cat', 'Small', 200),
#  ('25614cdac7f4d3', 'Cat', 'Small', 340),
#  ('051fd742638cfc', 'Cat', 'Large', 340),
#  ('999863740194d7', 'Dog', 'Large', 310),
#  ('bcc8588fbf7572', 'Dog', 'Large', 385),
#  ('d6dceea7e2aeea', 'Dog', 'Small', 260),
#  ('4018fa7f6cb6ac', 'Cat', 'Medium', 360),
#  ('913f26fbe07cd8', 'Dog', 'Medium', 440),
#  ('e777fde9598b07', 'Dog', 'Large', 465),
#  ('5ea4492e06d157', 'Dog', 'Large', 285),
#  ('28b6c703dbf48b', 'Bird', 'Small', 280),
#  ('787334e940ebc9', 'Cat', 'Medium', 405),
#  ('60db33e0480087', 'Cat', 'Large', 410),
#  ('9fcb8ad7227b65', 'Dog', 'Small', 345),
#  ('dedfa0a992553e', 'Dog', 'Medium', 435),
#  ('a8656197e7f92b', 'Dog', 'Small', 525),
#  ('2e6e9cd211ea26', 'Dog', 'Medium', 390),
#  ('368f28781dfd77', 'Dog', 'Large', 410),
#  ('43143c607b1044', 'Dog', 'Medium', 400),
#  ('864eabc83d5e1d', 'Dog', 'Small', 325),
#  ('95f18da35e30ac', 'Cat', 'Large', 240),
#  ('2cbfb147189327', 'Cat', 'Small', 385),
#  ('ded29e5b6b4d1b', 'Dog', 'Medium', 250),
#  ('6b986b284a700d', 'Cat', 'Small', 520),
#  ('c5c9cef472761b', 'Dog', 'Medium', 350),
#  ('0c7641ca5a8edc', 'Dog', 'Medium', 285),
#  ('edd7b1bd6f9665', 'Dog', 'Small', 385),
#  ('e15fd6ab7ef9d2', 'Dog', 'Large', 395),
#  ('bbf001e5353025', 'Dog', 'Large', 285),
#  ('5ed88d6993c245', 'Dog', 'Medium', 485),
#  ('b631d4fcfc6e6f', 'Cat', 'Small', 210),
#  ('9fa3fdf7957eea', 'Dog', 'Small', 245),
#  ('772df945475e8b', 'Cat', 'Large', 275),
#  ('2e2275caa63492', 'Dog', 'Large', 515),
#  ('ee5a4a4cc0131e', 'Dog', 'Medium', 390),
#  ('1c573e4786d9e5', 'Dog', 'Medium', 370),
#  ('a553b5d3699ceb', 'Dog', 'Large', 385),
#  ('c9c7e43280a1fa', 'Cat', 'Small', 335),
#  ('9d5f1171596e14', 'Dog', 'Large', 460),
#  ('05dfe87f1aafea', 'Dog', 'Large', 415),
#  ('4541c5a908e1a2', 'Dog', 'Medium', 285),
#  ('39f63bb74cfc46', 'Cat', 'Large', 380),
#  ('84cf9123d05eec', 'Dog', 'Small', 365),
#  ('581995483724fc', 'Cat', 'Small', 220),
#  ('a7740272770499', 'Cat', 'Small', 220),
#  ('5c70199b0f4f59', 'Dog', 'Medium', 290),
#  ('a5cea8e9df1d82', 'Cat', 'Small', 220),
#  ('fa865cf8826402', 'Dog', 'Large', 465),
#  ('57a93c5e3dbbac', 'Cat', 'Large', 275),
#  ('26cb1817723ad5', 'Dog', 'Medium', 385),
#  ('637a43ac18ad3a', 'Dog', 'Small', 225),
#  ('68607adcf15604', 'Dog', 'Large', 425),
#  ('c405740570a2a2', 'Cat', 'Small', 390),
#  ('8ea448a5cf01fa', 'Cat', 'Medium', 230),
#  ('021058af76fd12', 'Cat', 'Small', 235),
#  ('dff491566e4fc8', 'Cat', 'Large', 280),
#  ('02109f6e14b9cf', 'Cat', 'Medium', 240),
#  ('3214130319be26', 'Dog', 'Large', 460),
#  ('9399bdc023db04', 'Dog', 'Medium', 440),
#  ('5995fd325f6ca4', 'Cat', 'Small', 385),
#  ('8967431f2780bc', 'Dog', 'Small', 335),
#  ('08479b34f46b96', 'Cat', 'Small', 235),
#  ('07f1be720826a6', 'Dog', 'Medium', 350),
#  ('e4527691ba0b6b', 'Dog', 'Small', 235),
#  ('6beade33cf571e', 'Dog', 'Large', 310),
#  ('ae8e8e9e2e9413', 'Cat', 'Large', 250),
#  ('a9b201c7737d45', 'Dog', 'Large', 375),
#  ('7c0f625e43d512', 'Dog', 'Small', 245),
#  ('10192a57080ff5', 'Cat', 'Large', 375),
#  ('002c695223a556', 'Cat', 'Medium', 360),
#  ('bdcc51f1a5fe12', 'Dog', 'Medium', 435),
#  ('35ea3642e75eb4', 'Cat', 'Large', 380),
#  ('5bf6e2ff1de190', 'Dog', 'Large', 385),
#  ('f8a3e968509d2d', 'Dog', 'Large', 410),
#  ('9bb5e0020b5833', 'Cat', 'Medium', 370),
#  ('2f1d490766bf4f', 'Dog', 'Medium', 550),
#  ('103f08e0934654', 'Dog', 'Medium', 360),
#  ('05e4fab11a61de', 'Cat', 'Medium', 240),
#  ('d90caf9cb3af73', 'Dog', 'Small', 365),
#  ('7db6b439b75d8f', 'Cat', 'Medium', 260),
#  ('0603deef49d383', 'Cat', 'Small', 220),
#  ('2912d2c9739d17', 'Dog', 'Medium', 285),
#  ('81617bc4abdb75', 'Cat', 'Small', 340),
#  ('96f02999692161', 'Cat', 'Small', 300),
#  ('69a05fc122d879', 'Cat', 'Small', 210),
#  ('3efb04d94144f6', 'Cat', 'Medium', 405),
#  ('79694fb1f730bd', 'Cat', 'Medium', 370),
#  ('059dd55c68b12f', 'Cat', 'Small', 420),
#  ('b94827b13fd749', 'Dog', 'Large', 285),
#  ('220beaef92d1fc', 'Dog', 'Large', 410),
#  ('c886c21b78eb74', 'Dog', 'Small', 385),
#  ('e1779c9b86241f', 'Dog', 'Medium', 440),
#  ('03b4097a99c5c7', 'Dog', 'Large', 425),
#  ('d25a57c4c2714c', 'Cat', 'Large', 400),
#  ('7ba2122294475e', 'Cat', 'Medium', 255),
#  ('5d08a0eceec8fc', 'Cat', 'Small', 310),
#  ('9ec9de2b6023f7', 'Dog', 'Small', 335),
#  ('cd31e241443303', 'Cat', 'Medium', 355),
#  ('c2f0c5b36e42de', 'Dog', 'Large', 615),
#  ('9774ab48066c8a', 'Cat', 'Large', 375),
#  ('55e0614d9d183c', 'Dog', 'Medium', 485),
#  ('e94b40a3baad9d', 'Cat', 'Large', 375),
#  ('177ec7922067a1', 'Dog', 'Medium', 250),
#  ('28449b87288b78', 'Dog', 'Large', 395),
#  ('5c15a17c674077', 'Cat', 'Small', 210),
#  ('31f6ecbfe77876', 'Cat', 'Large', 280),
#  ('6871f7ef7af61b', 'Cat', 'Small', 535),
#  ('5beafd16699129', 'Dog', 'Large', 415),
#  ('1e0bc7c2e646f2', 'Dog', 'Large', 465),
#  ('642ee955c7dd20', 'Cat', 'Small', 235),
#  ('dae6697b14ba21', 'Dog', 'Medium', 435),
#  ('01eab02fb187d1', 'Cat', 'Small', 340),
#  ('799ad87be9ac58', 'Dog', 'Small', 345),
#  ('6321f46e7cddee', 'Cat', 'Small', 335),
#  ('6b2b017e0a6774', 'Dog', 'Medium', 435),
#  ('71613800ec7826', 'Cat', 'Large', 380),
#  ('b8f5787b86e1cd', 'Dog', 'Medium', 590),
#  ('9de551c45c57cb', 'Cat', 'Small', 210),
#  ('d87e2953cd5358', 'Dog', 'Large', 460),
#  ('89d3a4766496f0', 'Dog', 'Medium', 400),
#  ('f64479adf7c9ea', 'Dog', 'Small', 345),
#  ('9745f0026167cf', 'Cat', 'Small', 235),
#  ('a8467b12b75ead', 'Cat', 'Small', 220),
#  ('a07c12ac59be56', 'Cat', 'Medium', 355),
#  ('885e162d1ac7dd', 'Dog', 'Large', 395),
#  ('50ae8b623cc5b3', 'Bird', 'Large', 345),
#  ('f303aa272a98bd', 'Cat', 'Large', 450),
#  ('6be3716a4bdeff', 'Dog', 'Medium', 285),
#  ('35d56490c40c83', 'Dog', 'Large', 415),
#  ('450ba7ae202a06', 'Dog', 'Large', 445),
#  ('0e3ce0d477492c', 'Dog', 'Large', 425),
#  ('52b26a8375148b', 'Cat', 'Small', 310),
#  ('83571bbda2f88f', 'Cat', 'Small', 350),
#  ('c3d28cc0114dcc', 'Dog', 'Medium', 285),
#  ('8811d38bcbd1ea', 'Dog', 'Medium', 400),
#  ('11a30805414404', 'Dog', 'Large', 375),
#  ('83f981e2ca3e94', 'Dog', 'Large', 315),
#  ('f9343fa71b98c8', 'Dog', 'Large', 315),
#  ('24f31c308f1dcc', 'Cat', 'Medium', 355),
#  ('9ad70fbedadfc5', 'Dog', 'Small', 395),
#  ('010834267fb571', 'Dog', 'Medium', 260),
#  ('4b03d9b40accb1', 'Cat', 'Medium', 355),
#  ('2207b4f68bc244', 'Cat', 'Large', 280),
#  ('822582dd2f30a1', 'Dog', 'Small', 415),
#  ('6efd1ead32740c', 'Dog', 'Medium', 390),
#  ('7b14e873299487', 'Cat', 'Small', 300),
#  ('9db889b54f9c20', 'Dog', 'Large', 315),
#  ('b7688acfc41d06', 'Cat', 'Medium', 360),
#  ('c42243bb26464f', 'Dog', 'Large', 310),
#  ('e4b2eee02eb739', 'Cat', 'Medium', 240),
#  ('12341def30ce3d', 'Dog', 'Medium', 400),
#  ('b962debdc9b239', 'Dog', 'Medium', 435),
#  ('0af8185b66318f', 'Cat', 'Small', 300),
#  ('bef723f6d7d5c8', 'Cat', 'Small', 210),
#  ('f053f9927d6980', 'Dog', 'Large', 475),
#  ('124a98b23aac35', 'Dog', 'Large', 415),
#  ('53cc3b3237c24a', 'Dog', 'Medium', 440),
#  ('01f549b697c4e2', 'Dog', 'Small', 235),
#  ('a286ce4f83bac4', 'Cat', 'Large', 275),
#  ('1c35f2214116dd', 'Cat', 'Large', 250),
#  ('aae2ebaa780222', 'Cat', 'Large', 390),
#  ('1ab974eb0cdc23', 'Dog', 'Medium', 450),
#  ('74863b56eab53e', 'Cat', 'Small', 300),
#  ('459be8df90276a', 'Dog', 'Large', 310),
#  ('4dbf56a4614894', 'Cat', 'Medium', 320),
#  ('722d23d360e95c', 'Dog', 'Large', 460),
#  ('d3368a037fb7a6', 'Dog', 'Medium', 285),
#  ('c56df46588e96f', 'Dog', 'Medium', 440),
#  ('8d45dcadfd88e3', 'Cat', 'Large', 275),
#  ('73766bce237759', 'Cat', 'Small', 240),
#  ('3f4747ef54019f', 'Dog', 'Large', 410),
#  ('e971fb4bf90272', 'Cat', 'Small', 220),
#  ('99ec64c62a0be8', 'Cat', 'Small', 240),
#  ('f72c0378e4311d', 'Dog', 'Large', 410),
#  ('0a4af90839595e', 'Dog', 'Small', 385),
#  ('2b08ae61b0fc1b', 'Dog', 'Large', 460),
#  ('8977734aa89f7f', 'Dog', 'Large', 285),
#  ('cd362e6572906e', 'Cat', 'Medium', 240),
#  ('b9342bc5bb4c7c', 'Cat', 'Small', 335),
#  ('a8c020102e3ad2', 'Dog', 'Medium', 460),
#  ('692c7e368d8679', 'Dog', 'Large', 445),
#  ('ce38f03feffc8f', 'Dog', 'Large', 375),
#  ('a8b88656d8da7e', 'Dog', 'Large', 410),
#  ('88659436ea3373', 'Cat', 'Small', 320),
#  ('4a2c00fc0ee18d', 'Dog', 'Large', 310),
#  ('c0367a562dc375', 'Cat', 'Large', 390),
#  ('aa41afcd7443c3', 'Dog', 'Large', 275),
#  ('bf44acfd2a5295', 'Cat', 'Large', 340),
#  ('e7d590e277d97a', 'Cat', 'Small', 310),
#  ('bfa4da3187e951', 'Dog', 'Medium', 250),
#  ('a86ab21d40c947', 'Dog', 'Large', 385),
#  ('483bbd16d12a36', 'Cat', 'Large', 340),
#  ('2959254741b505', 'Dog', 'Small', 375),
#  ('e3047e59a802f7', 'Dog', 'Medium', 370),
#  ('6d9f770117c4d4', 'Dog', 'Large', 410),
#  ('337d08a0946e37', 'Cat', 'Medium', 220),
#  ('d99153a33c5fa2', 'Cat', 'Small', 385),
#  ('0fed34efec8545', 'Cat', 'Medium', 355),
#  ('b13b130f260109', 'Cat', 'Small', 340),
#  ('910ff3c55280a7', 'Dog', 'Small', 265),
#  ('b92312cea7b17e', 'Dog', 'Small', 345),
#  ('8a2b41b1c4fac6', 'Dog', 'Large', 375),
#  ('34c485e8bda70f', 'Dog', 'Large', 395),
#  ('24efaf52583291', 'Dog', 'Medium', 390),
#  ('10561138313b06', 'Dog', 'Medium', 285),
#  ('b1a0fe6d495c3d', 'Dog', 'Medium', 360),
#  ('d5649c0abd902f', 'Cat', 'Medium', 355),
#  ('94a69f403d0715', 'Dog', 'Large', 495),
#  ('8b3d37bb89b8ad', 'Cat', 'Small', 390),
#  ('913878e559bbd1', 'Dog', 'Medium', 360),
#  ('5a08158bad612c', 'Dog', 'Medium', 440),
#  ('509963b56639e1', 'Dog', 'Medium', 560),
#  ('db75a73c9b2438', 'Dog', 'Small', 365),
#  ('a651c1ace32940', 'Cat', 'Large', 425),
#  ('75d4f16595f0a7', 'Dog', 'Large', 395),
#  ('c7407a66d5b9af', 'Dog', 'Large', 375),
#  ('75c2f938804b89', 'Cat', 'Small', 535),
#  ('304a90cbe08c05', 'Dog', 'Large', 425),
#  ('ac5c7be9fdfc57', 'Cat', 'Small', 235),
#  ('72d5fd468afa3d', 'Dog', 'Medium', 290),
#  ('a10e6fba8c8faf', 'Dog', 'Medium', 290),
#  ('12d97370d2f821', 'Dog', 'Medium', 270),
#  ('08ec4b65588f59', 'Dog', 'Small', 415),
#  ('025d6c87d736ea', 'Dog', 'Medium', 390),
#  ('6f9332945d8611', 'Dog', 'Small', 325),
#  ('92b507cc9c0755', 'Dog', 'Medium', 270),
#  ('c51be33f35a236', 'Dog', 'Medium', 410),
#  ('b0848b4f5eab7a', 'Dog', 'Medium', 260),
#  ('fc47c877293420', 'Cat', 'Small', 320),
#  ('d2e4f6585676d3', 'Dog', 'Large', 445),
#  ('33f2c00951bb5f', 'Dog', 'Large', 515),
#  ('ccaf7a9e3abaaa', 'Cat', 'Large', 430),
#  ('a239392a58c450', 'Dog', 'Small', 335),
#  ('161930c4ab3a6f', 'Cat', 'Large', 340),
#  ('84387ef15236ca', 'Cat', 'Small', 210),
#  ('ab0d4e37fa990d', 'Dog', 'Small', 335),
#  ('d6fa98913dda79', 'Cat', 'Small', 410),
#  ('8d9317acdd5c7d', 'Cat', 'Small', 220),
#  ('334c14cd34e8fd', 'Dog', 'Small', 545),
#  ('e977ec57fc8506', 'Cat', 'Large', 240),
#  ('2aa0dab2802e84', 'Dog', 'Large', 435),
#  ('9155f6ae6f5ddd', 'Cat', 'Small', 360),
#  ('c8c0a6faee3c74', 'Dog', 'Large', 295),
#  ('dbe01378a5c933', 'Dog', 'Large', 315),
#  ('dd07abb2ef14f7', 'Cat', 'Large', 240),
#  ('e6798c87e81ecb', 'Dog', 'Large', 315),
#  ('f6c7dcdca83a2a', 'Dog', 'Small', 415),
#  ('9bf2943aff25ee', 'Bird', 'Large', 230),
#  ('fee51e26fd2d73', 'Cat', 'Large', 375),
#  ('179ff6f5cceab4', 'Cat', 'Large', 380),
#  ('6e1b1198935682', 'Dog', 'Small', 445),
#  ('15142b1eb45430', 'Cat', 'Small', 335),
#  ('a58cb434ccee78', 'Dog', 'Large', 375),
#  ('daf88b3f2a9121', 'Cat', 'Large', 400),
#  ('c704f1f7e212b1', 'Cat', 'Large', 390),
#  ('9e126dd0518f2b', 'Dog', 'Medium', 270),
#  ('14a333bc8dd3a6', 'Cat', 'Medium', 320),
#  ('143944444eb605', 'Cat', 'Small', 335),
#  ('bc848f130a7ea0', 'Dog', 'Medium', 440),
#  ('6c7d386cc585cc', 'Dog', 'Large', 410),
#  ('f82c7e00222cb2', 'Dog', 'Medium', 390),
#  ('1bc7d3aaea7c3e', 'Cat', 'Large', 380),
#  ('b26ca3e88c7cfb', 'Cat', 'Small', 240),
#  ('ba5e1b376aaa5b', 'Dog', 'Medium', 290),
#  ('e5d16064a38308', 'Dog', 'Large', 310),
#  ('e28dbfff524622', 'Dog', 'Medium', 385),
#  ('7161a0960db4ba', 'Cat', 'Small', 310),
#  ('14c1483bc78147', 'Cat', 'Large', 375),
#  ('e87199bb766b23', 'Dog', 'Small', 245),
#  ('fbc258f8c77f46', 'Dog', 'Medium', 410),
#  ('e06f6e3eaf6e8e', 'Dog', 'Small', 365),
#  ('419ef8324cca2a', 'Dog', 'Large', 375),
#  ('3b5af8b737d425', 'Cat', 'Small', 385),
#  ('3fb5ca5195803a', 'Dog', 'Small', 395),
#  ('01d6f271c54071', 'Cat', 'Large', 250),
#  ('bc4284c028e712', 'Dog', 'Large', 295),
#  ('7e311f5bb94cbf', 'Dog', 'Medium', 250),
#  ('9e6557d1387089', 'Cat', 'Small', 335),
#  ('1ab95f394247b2', 'Dog', 'Medium', 420),
#  ('414ce9bc028a29', 'Dog', 'Large', 445),
#  ('9eae189cde3fcb', 'Dog', 'Medium', 385),
#  ('55ef397cc3fcd7', 'Dog', 'Small', 365),
#  ('a0e94d789e9ef9', 'Cat', 'Medium', 320),
#  ('195485b898412d', 'Dog', 'Medium', 400),
#  ('c6d7387743be99', 'Dog', 'Small', 385),
#  ('a07312005e237a', 'Dog', 'Medium', 285),
#  ('42f6a72025b5be', 'Cat', 'Small', 390),
#  ('0ba6279f78cf2b', 'Dog', 'Large', 395),
#  ('697fa70ff10f34', 'Dog', 'Large', 410),
#  ('4d9a37d84fefa7', 'Dog', 'Large', 585),
#  ('0d35fc7f70b94b', 'Dog', 'Large', 510),
#  ('e41be97b23c916', 'Cat', 'Small', 220),
#  ('8ca4b317162123', 'Cat', 'Large', 275),
#  ('e9658db5ccbd53', 'Dog', 'Large', 410),
#  ('b254e7edb94e25', 'Cat', 'Small', 240),
#  ('6584af1247880d', 'Dog', 'Small', 360),
#  ('98392c8023114d', 'Dog', 'Medium', 435),
#  ('7e7c50f2b508a8', 'Cat', 'Large', 360),
#  ('a59ee5a60ca78d', 'Dog', 'Medium', 470),
#  ('810d04f6b35070', 'Dog', 'Small', 365),
#  ('b221333952181f', 'Dog', 'Small', 460),
#  ('64d4861b489b9f', 'Dog', 'Large', 425),
#  ('1bb01468894a95', 'Cat', 'Small', 390),
#  ('f900c6cd9f4b09', 'Dog', 'Large', 410),
#  ('4cd9b23d8bf41e', 'Cat', 'Small', 335),
#  ('b71e2ef30bbf07', 'Dog', 'Medium', 390),
#  ('fb3e69f7a13d03', 'Dog', 'Medium', 590),
#  ('2cc7c1e2954436', 'Dog', 'Medium', 360),
#  ('70dfe83de8d977', 'Dog', 'Medium', 440),
#  ('f6f5311fbc9f1a', 'Dog', 'Medium', 435),
#  ('97e846c5cef971', 'Cat', 'Small', 220),
#  ('2952928afe0692', 'Cat', 'Small', 240),
#  ('ee704fdd2699ca', 'Dog', 'Medium', 435),
#  ('98d940a451b224', 'Dog', 'Large', 610),
#  ('296b74fd3b657f', 'Dog', 'Large', 275),
#  ('887f375a22391b', 'Cat', 'Medium', 255),
#  ('9c890047f01acc', 'Cat', 'Small', 240),
#  ('eb8a0e25646342', 'Dog', 'Medium', 585),
#  ('476551f2c3deb7', 'Dog', 'Medium', 385),
#  ('13e9579a820379', 'Dog', 'Medium', 470),
#  ('68d107d8d559cc', 'Dog', 'Large', 510),
#  ('d3b1c1e3bee234', 'Dog', 'Large', 395),
#  ('1b3ade9e136912', 'Cat', 'Small', 240),
#  ('f66958e8f0bc7c', 'Cat', 'Large', 375),
#  ('3cf7706691aa87', 'Dog', 'Medium', 270),
#  ('0ad0b010d0c839', 'Dog', 'Small', 260),
#  ('a937703fbb3656', 'Dog', 'Medium', 360),
#  ('5d89a4752bdde0', 'Cat', 'Small', 310),
#  ('ca4d7568043efd', 'Cat', 'Small', 320),
#  ('b61a771ff4fb46', 'Dog', 'Large', 595),
#  ('17d89854f6d34f', 'Dog', 'Large', 515),
#  ('3b9f80c414a88e', 'Dog', 'Large', 415),
#  ('a3b6246683f11b', 'Cat', 'Medium', 255),
#  ('ce4c6c69467684', 'Cat', 'Small', 235),
#  ('228ffebbefa1f4', 'Dog', 'Medium', 250),
#  ('a0047d6c80ae3b', 'Dog', 'Large', 475),
#  ('97943e25d5a76f', 'Cat', 'Small', 240),
#  ('03ebb6b27bce46', 'Cat', 'Large', 340),
#  ('6cc31849df5e61', 'Cat', 'Large', 275),
#  ('8c11c081c4c5a1', 'Cat', 'Medium', 355),
#  ('416d7a93a98fa0', 'Dog', 'Large', 310),
#  ('501461ac621460', 'Dog', 'Large', 310),
#  ('e516dbdfa544c0', 'Dog', 'Large', 310),
#  ('fabb0902b32237', 'Cat', 'Small', 370),
#  ('28260a963b7ca3', 'Dog', 'Small', 235),
#  ('2015421df44891', 'Cat', 'Small', 220),
#  ('3ebbef792b1744', 'Dog', 'Medium', 440),
#  ('a1c3af3567185d', 'Dog', 'Medium', 290),
#  ('ac0df8a69fe58c', 'Cat', 'Medium', 255),
#  ('088fc7ee0d41b5', 'Dog', 'Large', 310),
#  ('16fd11d871fde7', 'Dog', 'Medium', 270),
#  ('3a8602b9ff1650', 'Cat', 'Large', 340),
#  ('e32665d302a6f6', 'Dog', 'Medium', 385),
#  ('9d579eabc21e78', 'Dog', 'Large', 445),
#  ('23182f102ea646', 'Cat', 'Small', 320),
#  ('62c81e85b08678', 'Dog', 'Small', 375),
#  ('50875985c5499e', 'Cat', 'Medium', 255),
#  ('5fd2b1a54682cf', 'Cat', 'Small', 310),
#  ('f038e73a841a4a', 'Dog', 'Large', 460),
#  ('674deca7a2f325', 'Dog', 'Medium', 435),
#  ('6ded05447c03bf', 'Dog', 'Medium', 350),
#  ('b5b1f889afbccf', 'Dog', 'Medium', 290),
#  ('f3e0521b565c90', 'Cat', 'Large', 425),
#  ('6560adcf377bc9', 'Cat', 'Medium', 240),
#  ('09fef13d0694c3', 'Cat', 'Small', 240),
#  ('fcd6ec0a1f4076', 'Cat', 'Large', 360),
#  ('31eda17c5b193c', 'Dog', 'Medium', 390),
#  ('7898ec41b4e709', 'Cat', 'Medium', 260),
#  ('6b4ed00594ef47', 'Dog', 'Medium', 285),
#  ('74da35e1b6dc26', 'Dog', 'Large', 395),
#  ('c3000133f91a5a', 'Cat', 'Small', 220),
#  ('83f385c64caeda', 'Dog', 'Large', 415),
#  ('3a87a75706c9e5', 'Dog', 'Small', 415),
#  ('4be9f8aa719fa7', 'Cat', 'Small', 340),
#  ('5961ed7582988f', 'Dog', 'Medium', 420),
#  ('4dbfd8cd0609c0', 'Dog', 'Medium', 440),
#  ('784e76834740de', 'Dog', 'Medium', 260),
#  ('2a563ec9bb6f03', 'Cat', 'Large', 260),
#  ('fe07bf3691f5ce', 'Dog', 'Medium', 350),
#  ('bbe87cc08aa260', 'Cat', 'Small', 300),
#  ('c7e3eac29e1ee5', 'Dog', 'Large', 410),
#  ('c1ef6d728f30ae', 'Dog', 'Medium', 260),
#  ('3e4f1164bd8176', 'Dog', 'Large', 295),
#  ('042e24aa394458', 'Dog', 'Large', 595),
#  ('66f1e7bc9c45ad', 'Cat', 'Medium', 240),
#  ('9d29f12de81cbd', 'Dog', 'Large', 315),
#  ('0945da1d087fda', 'Dog', 'Small', 415),
#  ('6c8ae0b5d40acc', 'Dog', 'Large', 445),
#  ('c57b0d578427c1', 'Dog', 'Medium', 385),
#  ('04fca9faaecd0f', 'Cat', 'Small', 240),
#  ('a348df6b521ac5', 'Dog', 'Large', 610),
#  ('6cebe37df540c2', 'Cat', 'Large', 390),
#  ('01ecdea4c0ed30', 'Cat', 'Large', 375),
#  ('7c0ccf8c511be2', 'Cat', 'Small', 335),
#  ('03c8e105fe91b5', 'Cat', 'Large', 380),
#  ('dee6b686d68587', 'Cat', 'Medium', 355),
#  ('5d46c6a96f0c80', 'Dog', 'Large', 315),
#  ('ac178f4f69e810', 'Cat', 'Large', 280),
#  ('943adf65f577c7', 'Cat', 'Small', 335),
#  ('b48ff692e744d8', 'Dog', 'Large', 385),
#  ('9cb52b8f21b9b2', 'Cat', 'Small', 235),
#  ('aef341702a1097', 'Dog', 'Medium', 590),
#  ('479940d20dfd0f', 'Dog', 'Medium', 560),
#  ('2fbd1defe33ce0', 'Cat', 'Small', 340),
#  ('92914b46e97bee', 'Dog', 'Small', 345),
#  ('89b3859028fdda', 'Dog', 'Medium', 250),
#  ('656e628dd64804', 'Cat', 'Large', 250),
#  ('ec6b7c0db8d420', 'Cat', 'Small', 300),
#  ('74cdcca7cffee4', 'Cat', 'Small', 300),
#  ('f655175b31d81e', 'Dog', 'Large', 375),
#  ('198744c56ee2a8', 'Cat', 'Small', 235),
#  ('57f97a6d694d78', 'Dog', 'Medium', 435),
#  ('6798740a6713ce', 'Dog', 'Medium', 400),
#  ('b823c35f4d237c', 'Dog', 'Large', 295),
#  ('da5618206af29b', 'Cat', 'Small', 200),
#  ('4efdbd862d958b', 'Dog', 'Small', 360),
#  ('475036b16ad389', 'Dog', 'Medium', 490),
#  ('e3d7aa9c60a4df', 'Cat', 'Large', 280),
#  ('2820ca968edce3', 'Cat', 'Small', 235),
#  ('f2215688054068', 'Cat', 'Medium', 320),
#  ('446d71ce0c1585', 'Dog', 'Large', 315),
#  ('dbc263c37e17d9', 'Cat', 'Small', 385),
#  ('0224100f50a776', 'Cat', 'Medium', 410),
#  ('eec30d72ea9262', 'Cat', 'Small', 385),
#  ('7e2596ae7df688', 'Cat', 'Small', 340),
#  ('56d8739ef6cbe1', 'Cat', 'Large', 350),
#  ('113e732a156d23', 'Dog', 'Large', 310),
#  ('f1202a4ed99889', 'Dog', 'Medium', 250),
#  ('347b32129a3843', 'Cat', 'Medium', 410),
#  ('83ed32040ce829', 'Dog', 'Medium', 385),
#  ('873b4c61eb39c8', 'Dog', 'Medium', 385),
#  ('f4ec7669dfd255', 'Cat', 'Large', 280),
#  ('ea38d5039d5c3c', 'Cat', 'Medium', 340),
#  ('26b7cb2afc007e', 'Cat', 'Small', 340),
#  ('7d39e1bd4cb416', 'Dog', 'Medium', 360),
#  ('d73606ea7fa069', 'Cat', 'Large', 280),
#  ('799ad62091d2b0', 'Cat', 'Medium', 410),
#  ('9bd7e0e96d03de', 'Dog', 'Medium', 400),
#  ('6187cb42e8a9ac', 'Dog', 'Medium', 350),
#  ('3378eef49d324e', 'Cat', 'Small', 360),
#  ('04175575c7d94f', 'Dog', 'Medium', 440),
#  ('8497038877a150', 'Cat', 'Small', 335),
#  ('c05f9a96a7cf83', 'Dog', 'Large', 460),
#  ('cea1fc3c0d6983', 'Dog', 'Large', 465),
#  ('73bb453b21bd7b', 'Dog', 'Large', 435),
#  ('72e29754e694d5', 'Cat', 'Small', 340),
#  ('d587c746cedd7a', 'Cat', 'Large', 280),
#  ('f9e3083e831dff', 'Dog', 'Large', 425),
#  ('8a34640fc7e746', 'Cat', 'Small', 335),
#  ('2a790e28030eb4', 'Cat', 'Large', 275),
#  ('971a5b6e708897', 'Dog', 'Medium', 290),
#  ('77738fc71cb5f2', 'Cat', 'Medium', 360),
#  ('80193c447da353', 'Dog', 'Large', 385),
#  ('6a3073536351b6', 'Dog', 'Small', 565),
#  ('6e59d6c72ba19c', 'Dog', 'Large', 410),
#  ('92e83a5ea28fb9', 'Dog', 'Large', 410),
#  ('fdd6a83611ae8f', 'Dog', 'Medium', 285),
#  ('56cad86c0fcf72', 'Dog', 'Medium', 420),
#  ('276682b2e7f0ef', 'Dog', 'Large', 595),
#  ('65f45dd1da6171', 'Cat', 'Large', 250),
#  ('25b7dbc8484110', 'Cat', 'Small', 335),
#  ('f60aac9816631c', 'Dog', 'Medium', 285),
#  ('cba781aa20a13b', 'Dog', 'Large', 410),
#  ('f6dfdc61b17360', 'Cat', 'Large', 250),
#  ('d2ee1be5943beb', 'Dog', 'Large', 435),
#  ('f1b790d42b4e59', 'Cat', 'Large', 375),
#  ('93a23d62a6e9d4', 'Dog', 'Medium', 400),
#  ('5413831217941f', 'Dog', 'Large', 375),
#  ('e5dc720a4b88cc', 'Cat', 'Large', 280),
#  ('6c85add7395981', 'Dog', 'Medium', 550),
#  ('8b53ac0e323b4b', 'Cat', 'Small', 235),
#  ('16a02ade950a96', 'Dog', 'Large', 315),
#  ('d51c19751dc5f8', 'Dog', 'Large', 435),
#  ('a23ef8270330fb', 'Dog', 'Medium', 285),
#  ('da1e494f80001c', 'Cat', 'Small', 385),
#  ('4e32e059f218f2', 'Dog', 'Medium', 370),
#  ('3519a69567ba6e', 'Cat', 'Medium', 330),
#  ('a3d1815f6f716e', 'Cat', 'Large', 375),
#  ('4be3207c1bae33', 'Cat', 'Small', 240),
#  ('3441c09f1f151d', 'Dog', 'Large', 275),
#  ...]

# %%
# %%sql
# postgresql:///animal_shelters
#
#
#     select lower(animaltype) as animaltype,lower(size) as size,total, round(total*100/sum(total) over(),2) as percentage
#     from(
#
#         select animaltype,size,sum(total) as total
#         from(
#
#             select animalid,table1.animaltype,size,
#             (age_costs.costs+location_costs.costs+size_costs.costs) as total
#             from (select animalid,animaltype,location,
#                 cast((extract(year from age(date('2021-12-31'),
#                                             date(birthdate)))) as integer) as age,
#                 case when animaltype='Dog' and weight<=10 then 'DS'
#                 when animaltype='Dog' and weight<=30 then 'DM'
#                 when animaltype='Dog' and weight>30 then 'DL'
#                 when animaltype='Cat' and weight<=5 then 'CS'
#                 when animaltype='Cat' and weight<=7 then 'CM'
#                 when animaltype='Cat' and weight>7 then 'CL'
#                 when animaltype='Bird' and weight<=0.7 then 'BS'
#                 when animaltype='Bird' and weight<=1.1 then 'BM'
#                 else 'BL' end as sizeid
#                 from animals)
#             as table1
#             left join location_costs on location_costs.location=table1.location
#             left join size_costs on size_costs.sizeid=table1.sizeid
#             left join (select cast(age as integer),costs from age_costs) as age_costs
#             on age_costs.age=table1.age
#             where animalid not in (select sponsorid from sponsored_animals)
#         )
#         as table2
#         group by animaltype,size) as table3
#     order by animaltype,size desc
# Out:
# 9 rows affected.
# [('bird', 'small', 1615, Decimal('0.05')),
#  ('bird', 'medium', 3460, Decimal('0.10')),
#  ('bird', 'large', 7770, Decimal('0.22')),
#  ('cat', 'small', 518015, Decimal('14.90')),
#  ('cat', 'medium', 250575, Decimal('7.21')),
#  ('cat', 'large', 439490, Decimal('12.64')),
#  ('dog', 'small', 336530, Decimal('9.68')),
#  ('dog', 'medium', 941895, Decimal('27.09')),
#  ('dog', 'large', 977665, Decimal('28.12'))]
